# %% [raw]
# ---
# title: Analyse NDVI — Sine-Saloum
# description: Calcul et visualisation du NDVI sur les zones de mangrove avec Rasterio et Matplotlib.
# image: ""
# tags:
#   - Python
#   - Rasterio
#   - NDVI
#   - Télédétection
# category: teledetection
# status: terminé
# date: "2025-04-10"
# link: https://github.com/darcman0
# ---

# %% [markdown]
# # hello
